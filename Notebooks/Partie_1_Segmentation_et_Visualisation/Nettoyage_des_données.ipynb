# %%
import pandas as pd

# %%
# # Charger le fichier Excel
# xls = pd.ExcelFile('../../data/data.xlsx')

# # Charger les données de l'année 2009-2010
# df_2009_2010 = pd.read_excel(xls, 'Year 2009-2010')
# df_2009_2010.to_csv('../../data/df_2009_2010.csv', index=False)

# # Charger les données de l'année 2010-2011
# df_2010_2011 = pd.read_excel(xls, 'Year 2010-2011')
# df_2010_2011.to_csv('../../data/df_2010_2011.csv', index=False)

# %%
df_2009_2010 = pd.read_csv('../../data/df_2009_2010.csv')
df_2010_2011 = pd.read_csv('../../data/df_2010_2011.csv')

df_concat = pd.concat([df_2009_2010, df_2010_2011], ignore_index=True)

# %%
df_concat
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df_concat.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  object
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 65.1+ MB

# %%
df_concat.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %%
# montre moi les lignes nulles pour la colonne description
df_null_customer = df_concat[df_concat['Customer ID'].isnull()]
# regarde quand le description et le customer est null
df_null_customer_description = df_null_customer[df_null_customer['Description'].isnull()]
# montre moi toute les valeurs dans le price
df_null_customer_description['Price'].value_counts()
# Out:
# 0.0    4382
# Name: Price, dtype: int64

# %%
# montre le df_null_customer_description ou le pays est l'united kingdom
df_null_customer_description[df_null_customer_description['Country'] == 'United Kingdom']
# Out:
#         Invoice StockCode Description  Quantity          InvoiceDate  Price  \
# 470      489521     21646         NaN       -50  2009-12-01 11:44:00    0.0
# 3114     489655     20683         NaN       -44  2009-12-01 17:26:00    0.0
# 3161     489659     21350         NaN       230  2009-12-01 17:39:00    0.0
# 3731     489781     84292         NaN        17  2009-12-02 11:45:00    0.0
# 4296     489806     18010         NaN      -770  2009-12-02 12:42:00    0.0
# ...         ...       ...         ...       ...                  ...    ...
# 1060783  581199     84581         NaN        -2  2011-12-07 18:26:00    0.0
# 1060787  581203     23406         NaN        15  2011-12-07 18:31:00    0.0
# 1060793  581209     21620         NaN         6  2011-12-07 18:35:00    0.0
# 1062442  581234     72817         NaN        27  2011-12-08 10:33:00    0.0
# 1064015  581408     85175         NaN        20  2011-12-08 14:06:00    0.0
#
#          Customer ID         Country
# ...

# %%
# Supprimer les lignes où 'Description' et 'Customer ID' sont tous les deux nuls
df_clean = df_concat.dropna(subset=['Description', 'Customer ID'], how='all')
df_clean
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
# combien null customer id
df_clean['Customer ID'].isnull().sum()
# Out:
# 238625

# %%
# montre le df clean tous les description null
df__customer_id_null = df_clean[df_clean['Customer ID'].isnull()]
df__customer_id_null.head(30)
# Out:
#      Invoice StockCode                       Description  Quantity  \
# 263   489464     21733                      85123a mixed       -96
# 283   489463     71477                             short      -240
# 284   489467    85123A                       21733 mixed      -192
# 577   489525    85226C         BLUE PULL BACK RACING CAR         1
# 578   489525     85227       SET/6 3D KIT CARDS FOR KIDS         1
# 1055  489548     22271              FELTCRAFT DOLL ROSIE         1
# 1056  489548     22254              FELT TOADSTOOL LARGE        12
# 1057  489548     22273              FELTCRAFT DOLL MOLLY         3
# 1058  489548     22195      LARGE HEART MEASURING SPOONS         1
# 1059  489548     22131  FOOD CONTAINER SET 3 LOVE HEART          2
# 1060  489548     22079        RIBBON REEL HEARTS DESIGN         10
# 1061  489548     22138     BAKING SET 9 PIECE RETROSPOT          3
# 1062  489548     22147        FELTCRAFT BUTTERFLY HEARTS         2
# ...

# %%
# enleve moi les lignes ou le customer id est null
df_clean = df_clean.dropna(subset=['Customer ID'])
df_clean
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
# montre valeur null
df_clean.isnull().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
# combien de ligne dont la colonne Invoice commencer par c
df_clean[df_clean['Invoice'].str.startswith('C')].shape[0]
# Out:
# 18744

# %%
# Supprimer les transactions annulées
df_clean = df_clean[~df_clean['Invoice'].str.startswith('C')]

# %%
df_clean
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
# verifie la colonne Invoice qui fait plus de 6 chiffre
df_clean[df_clean['Invoice'].str.len() > 6]
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country]
# Index: []

# %%
# verifie la colonne StockCode  qui fait plus de 5 chiffre on les retires ces lignes
df_clean = df_clean[df_clean['StockCode'].str.len() <= 5]

# verifie la colonne StockCode  qui fait moins de 5 chiffre on les retires ces lignes
df_clean = df_clean[df_clean['StockCode'].str.len() >= 5]

df_clean
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# 5        489434     22064           PINK DOUGHNUT TRINKET POT         24
# 6        489434     21871                  SAVE THE PLANET MUG        24
# ...         ...       ...                                  ...       ...
# 1067365  581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
# verifie si il a pas de chaine de caractere dans la colonne StockCode
df_clean[~df_clean['StockCode'].str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country]
# Index: []

# %%
# remplacer les espaces dans le nom des colonnes par des _ et aussi enlever les espaces en debut et fin de chaine
df_clean.columns = df_clean.columns.str.replace(' ', '_').str.strip()
# remplace les espaces dans les colonnes str par des _ et enleve les espaces en debut et fin de chaine
df_clean['Description'] = df_clean['Description'].str.strip().str.replace(' ', '_')
df_clean['Country'] = df_clean['Country'].str.strip().str.replace(' ', '_')

df_clean
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM_CHRISTMAS_GLASS_BALL_20_LIGHTS        12
# 3        489434     22041          RECORD_FRAME_7"_SINGLE_SIZE        48
# 4        489434     21232       STRAWBERRY_CERAMIC_TRINKET_BOX        24
# 5        489434     22064            PINK_DOUGHNUT_TRINKET_POT        24
# 6        489434     21871                  SAVE_THE_PLANET_MUG        24
# ...         ...       ...                                  ...       ...
# 1067365  581587     22613          PACK_OF_20_SPACEBOY_NAPKINS        12
# 1067366  581587     22899          CHILDREN'S_APRON_DOLLY_GIRL         6
# 1067367  581587     23254         CHILDRENS_CUTLERY_DOLLY_GIRL         4
# 1067368  581587     23255      CHILDRENS_CUTLERY_CIRCUS_PARADE         4
# 1067369  581587     22138         BAKING_SET_9_PIECE_RETROSPOT         3
#
#                  InvoiceDate  Price  Customer_ID         Country
# ...

# %%
# description value counts
df_clean['Description'].value_counts()
# Out:
# REGENCY_CAKESTAND_3_TIER         3430
# ASSORTED_COLOUR_BIRD_ORNAMENT    2777
# REX_CASH+CARRY_JUMBO_SHOPPER     2141
# PARTY_BUNTING                    2122
# LUNCH_BAG__BLACK_SKULL.          2117
#                                  ...
# NUMBER_TILE_VINTAGE_FONT,_7         1
# NUMBER_TILE_VINTAGE_FONT,_6         1
# NUMBER_TILE_VINTAGE_FONT,_5         1
# NUMBER_TILE_VINTAGE_FONT,_4         1
# PAPER_CRAFT_,_LITTLE_BIRDIE         1
# Name: Description, Length: 3860, dtype: int64

# %%
# montre ou la colonnes quantity est inferieur a 0
df_clean[df_clean['Quantity'] <= 0]
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer_ID, Country]
# Index: []

# %%
# montre moi la colonne InvoiceDate sont type
df_clean.dtypes
# Out:
# Invoice         object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# Price          float64
# Customer_ID    float64
# Country         object
# dtype: object

# %%
df_clean['InvoiceDate'] = pd.to_datetime(df_clean['InvoiceDate'])

# %%
df_clean.dtypes
# Out:
# Invoice                object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# Price                 float64
# Customer_ID           float64
# Country                object
# dtype: object

# %%
# mainteant pour la colonne Price on va enlever les valeurs negatives
df_clean[df_clean['Price'] < 0]
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer_ID, Country]
# Index: []

# %%
# Pour la colonne Customer ID on va enlever les valeurs negatives
df_clean[df_clean['Customer_ID'] < 0]
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer_ID, Country]
# Index: []

# %%
# met le customer id en int
df_clean['Customer_ID'] = df_clean['Customer_ID'].astype(int)
df_clean
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM_CHRISTMAS_GLASS_BALL_20_LIGHTS        12
# 3        489434     22041          RECORD_FRAME_7"_SINGLE_SIZE        48
# 4        489434     21232       STRAWBERRY_CERAMIC_TRINKET_BOX        24
# 5        489434     22064            PINK_DOUGHNUT_TRINKET_POT        24
# 6        489434     21871                  SAVE_THE_PLANET_MUG        24
# ...         ...       ...                                  ...       ...
# 1067365  581587     22613          PACK_OF_20_SPACEBOY_NAPKINS        12
# 1067366  581587     22899          CHILDREN'S_APRON_DOLLY_GIRL         6
# 1067367  581587     23254         CHILDRENS_CUTLERY_DOLLY_GIRL         4
# 1067368  581587     23255      CHILDRENS_CUTLERY_CIRCUS_PARADE         4
# 1067369  581587     22138         BAKING_SET_9_PIECE_RETROSPOT         3
#
#                 InvoiceDate  Price  Customer_ID         Country
# ...

# %%
# Pour le customer id vérifie sa taille et enleve les lignes qui font plus de 5 chiffres
df_clean = df_clean[df_clean['Customer_ID'].astype(str).str.len() <= 5]
# Pour le customer id vérifie sa taille et enleve les lignes qui font moins de 5 chiffres
df_clean = df_clean[df_clean['Customer_ID'].astype(str).str.len() >= 5]

df_clean
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM_CHRISTMAS_GLASS_BALL_20_LIGHTS        12
# 3        489434     22041          RECORD_FRAME_7"_SINGLE_SIZE        48
# 4        489434     21232       STRAWBERRY_CERAMIC_TRINKET_BOX        24
# 5        489434     22064            PINK_DOUGHNUT_TRINKET_POT        24
# 6        489434     21871                  SAVE_THE_PLANET_MUG        24
# ...         ...       ...                                  ...       ...
# 1067365  581587     22613          PACK_OF_20_SPACEBOY_NAPKINS        12
# 1067366  581587     22899          CHILDREN'S_APRON_DOLLY_GIRL         6
# 1067367  581587     23254         CHILDRENS_CUTLERY_DOLLY_GIRL         4
# 1067368  581587     23255      CHILDRENS_CUTLERY_CIRCUS_PARADE         4
# 1067369  581587     22138         BAKING_SET_9_PIECE_RETROSPOT         3
#
#                 InvoiceDate  Price  Customer_ID         Country
# ...

# %%
# value counts de la colonne Country
df_clean['Country'].value_counts()
# Out:
# United_Kingdom          642490
# Germany                  14766
# EIRE                     13905
# France                   12460
# Netherlands               4669
# Spain                     3255
# Belgium                   2689
# Switzerland               2678
# Portugal                  2215
# Australia                 1698
# Channel_Islands           1455
# Norway                    1322
# Italy                     1306
# Sweden                    1198
# Cyprus                    1037
# Finland                    828
# Austria                    818
# Denmark                    704
# Greece                     574
# Poland                     449
# Japan                      447
# Unspecified                446
# USA                        367
# United_Arab_Emirates       340
# Singapore                  306
# Israel                     293
# Malta                      234
# Iceland                    216
# Canada                     197
# Lithuania                  163
# ...

# %%
# enleve les lignes de la colonne Country qui sont Unspecified
df_clean = df_clean[df_clean['Country'] != 'Unspecified']

# %%
df_clean
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM_CHRISTMAS_GLASS_BALL_20_LIGHTS        12
# 3        489434     22041          RECORD_FRAME_7"_SINGLE_SIZE        48
# 4        489434     21232       STRAWBERRY_CERAMIC_TRINKET_BOX        24
# 5        489434     22064            PINK_DOUGHNUT_TRINKET_POT        24
# 6        489434     21871                  SAVE_THE_PLANET_MUG        24
# ...         ...       ...                                  ...       ...
# 1067365  581587     22613          PACK_OF_20_SPACEBOY_NAPKINS        12
# 1067366  581587     22899          CHILDREN'S_APRON_DOLLY_GIRL         6
# 1067367  581587     23254         CHILDRENS_CUTLERY_DOLLY_GIRL         4
# 1067368  581587     23255      CHILDRENS_CUTLERY_CIRCUS_PARADE         4
# 1067369  581587     22138         BAKING_SET_9_PIECE_RETROSPOT         3
#
#                 InvoiceDate  Price  Customer_ID         Country
# ...

# %%
# quantite suppier a 10000
df_clean[df_clean['Quantity'] > 44000]
# Out:
#         Invoice StockCode                     Description  Quantity  \
# 587080   541431     23166  MEDIUM_CERAMIC_TOP_STORAGE_JAR     74215
# 1065882  581483     23843     PAPER_CRAFT_,_LITTLE_BIRDIE     80995
#
#                 InvoiceDate  Price  Customer_ID         Country
# 587080  2011-01-18 10:01:00   1.04        12346  United_Kingdom
# 1065882 2011-12-09 09:15:00   2.08        16446  United_Kingdom

# %%
df_clean
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM_CHRISTMAS_GLASS_BALL_20_LIGHTS        12
# 3        489434     22041          RECORD_FRAME_7"_SINGLE_SIZE        48
# 4        489434     21232       STRAWBERRY_CERAMIC_TRINKET_BOX        24
# 5        489434     22064            PINK_DOUGHNUT_TRINKET_POT        24
# 6        489434     21871                  SAVE_THE_PLANET_MUG        24
# ...         ...       ...                                  ...       ...
# 1067365  581587     22613          PACK_OF_20_SPACEBOY_NAPKINS        12
# 1067366  581587     22899          CHILDREN'S_APRON_DOLLY_GIRL         6
# 1067367  581587     23254         CHILDRENS_CUTLERY_DOLLY_GIRL         4
# 1067368  581587     23255      CHILDRENS_CUTLERY_CIRCUS_PARADE         4
# 1067369  581587     22138         BAKING_SET_9_PIECE_RETROSPOT         3
#
#                 InvoiceDate  Price  Customer_ID         Country
# ...

# %%
# met le fichier df_clean en csv
df_clean.to_csv('../../data/df_analyse.csv', index=False)
